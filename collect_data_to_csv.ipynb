# %%
pip install pyserial
# Out:
# Collecting pyserial
#   Downloading pyserial-3.5-py2.py3-none-any.whl.metadata (1.6 kB)
# Downloading pyserial-3.5-py2.py3-none-any.whl (90 kB)
# Installing collected packages: pyserial
# Successfully installed pyserial-3.5
# Note: you may need to restart the kernel to use updated packages.

# %%
import serial
import csv
import time

# Set up the serial connection
ser = serial.Serial('COM3', 9600)  # Replace 'COM_PORT' with your port, e.g., 'COM3' or '/dev/ttyACM0'
time.sleep(2)  # Wait for the serial connection to initialize

# Open a CSV file to save the data
with open('sensor_data.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Timestamp', 'X', 'Y', 'Z'])  # Write the header row

    while True:
        if ser.in_waiting > 0:  # Check if there's data in the serial buffer
            data = ser.readline().decode('utf-8').strip()  # Read a line of data
            # Split the data by commas (assuming it's in CSV format)
            values = data.split(',')
            
            if len(values) == 4:  # Check that we have the correct number of values (timestamp, x, y, z)
                writer.writerow(values)  # Write the data to the CSV file
                print(data)  # Optionally print it to the console
# Out:
# Timestamp,X,Y,Z
# 17996,-1.53,-0.92,2.14
# 18996,1.22,-0.61,2.01
# 19996,1.10,-0.79,1.95
# 20996,7.39,-1.53,4.76
# 21996,-10.19,0.37,0.92
# 22996,19.17,-1.10,2.69
# 23996,10.13,-9.16,-0.18
# 24996,6.47,-1.22,2.32
# 25996,2.56,-1.16,2.01
# 26996,1.53,-0.73,1.89
# 27996,1.89,-0.73,1.77
# 28996,0.43,-0.79,1.71
# 29996,1.59,-1.71,2.08
# 30996,0.00,-0.06,2.26
# 31996,0.55,0.79,2.26
# 32996,-0.12,-0.37,2.01
# 33996,1.53,-0.67,1.95
# 34996,-0.43,-0.18,1.95
# 35996,1.59,-1.65,2.08
# 36996,0.55,-0.98,1.83
# 37996,0.43,-0.37,1.83
# 38996,2.01,-2.38,2.26
# 39996,1.40,2.87,1.10
# 40996,-1.53,0.24,0.12
# 41996,-0.12,0.00,2.08
# 42996,0.79,-0.24,1.59
# 43996,1.46,-0.43,1.95
# 44996,1.95,-0.92,2.08
# 45996,-0.67,-0.43,1.46
# 46996,1.34,-0.79,1.83
# 47996,0.92,-0.73,1.77
# 48996,0.55,-0.67,1.77
# 49996,-10.44,1.83,0.79
# 50996,28.26,-32.71,-48.46
# 51996,-2.20,-0.31,0.79
# 52996,-0.61,0.55,2.01
# 53996,0.61,-0.49,2.08
# 54996,-10.93,3.36,2.32
# 55996,6.16,-12.27,-2.69
# 56996,20.75,-12.94,-28.26
# 57996,-62.19,16.42,25.02
# 58996,-40.77,-1.04,-10.74
# 59996,5.98,-11.90,-34.24
# 60996,46.45,-5.55,-23.93
# 61996,25.94,-12.88,-1.40
# 62996,3.91,-1.04,2.56
# 63996,0.79,-0.61,1.83
# 64996,0.85,-1.10,1.83
# 65996,1.59,-1.22,1.89
# 66996,0.67,-0.67,1.89
# 67996,-2.75,-0.55,0.31
# 68996,1.28,-0.43,2.56
# 69996,-0.73,8.12,34.67
# 70996,19.23,-8.00,-2.69
# 71996,31.25,6.59,-18.31
# 72996,-56.88,13.79,-17.70
# 73996,-3.78,0.67,1.28
# 74996,30.52,-3.97,7.93
# 75996,7.14,3.05,37.23
# 76996,-8.12,-6.29,10.25
# 77996,-5.31,2.87,-0.73
# 78996,5.49,-2.44,4.70
# 79996,-44.49,6.29,9.16
# 80996,18.98,-4.15,11.54
# 81996,11.29,-2.69,1.04
# 82996,-19.29,9.77,-6.59
# 83996,-0.18,-8.12,5.00
# 174996,1.71,-0.24,3.17
# 175996,-24.29,6.59,-10.01
# 176996,1.16,13.31,-7.20
# 177996,-12.94,4.21,18.74
# 178996,1.77,-0.79,5.98
# 179996,-11.84,9.89,39.18
# 180996,-2.69,4.94,33.33
# 181996,13.12,-3.48,-5.98
# 182996,5.19,-1.22,1.89
# 183996,2.69,-0.49,2.69
# 184996,0.79,-0.98,1.71
# 185996,-39.73,14.10,-4.82
# 186996,-2.99,10.99,-8.06
# 187996,8.73,-8.85,7.75
# 188996,3.42,8.48,-4.03
# 189996,13.49,-12.94,14.47
# 190996,9.09,18.98,-8.36
# 191996,-19.47,-3.23,21.97
# 192996,12.08,-2.69,5.86
# 193996,-1.53,-7.39,8.00
# 194996,17.58,10.80,-8.91
# 195996,27.89,-3.30,14.34
# 196996,-26.37,-7.39,-2.01
# 197996,3.17,-2.69,5.86
# 198996,4.39,11.60,0.67
# 199996,1.28,-3.23,-3.42
# 200996,-4.76,1.46,-5.86
# 201996,-26.67,-14.71,8.48
# 202996,9.22,8.30,-4.15
# 203996,-8.30,-10.13,6.59
# 204996,9.28,11.54,-6.16
# 205996,-6.29,-9.58,5.62
# 206996,14.59,11.96,-5.86
# 207996,-1.22,-10.99,6.71
# 208996,-0.31,-1.95,3.23
# 209996,9.77,9.89,-2.69
# 210996,-8.61,-2.69,5.13
# 211996,-5.49,-11.05,8.48
# 212996,6.10,10.07,-5.68
# 213996,1.34,3.97,-4.09
# 214996,17.21,-5.31,-30.70
# 215996,-11.17,-12.02,-17.52
# 216996,1.59,0.18,0.73
# 217996,-63.96,12.70,-5.68
# 218996,-0.92,-1.65,3.60
# 219996,-1.22,1.04,25.76
# 220996,21.36,-7.69,1.28
# 221996,6.59,-0.61,0.85
# 222996,6.04,8.42,-2.01
# 223996,-4.94,-4.15,-9.58
# 224996,2.81,-6.59,-13.24
# 225996,3.97,-0.18,1.77
# 226996,0.73,-0.49,1.77
# 227996,1.83,-0.06,1.89
# 228996,4.39,0.18,2.01
# 229996,-16.05,2.50,1.71
# 230996,-6.53,17.88,22.52
# 231996,24.29,-17.15,-20.26
# 232996,-14.65,-6.77,4.82
# 233996,-20.08,33.57,38.45
# 234996,-0.98,-27.28,-41.38
# 235996,-4.15,-0.49,-2.56
# 236996,0.73,-0.92,1.71
# 237996,1.71,-0.73,1.89
# 238996,0.00,-0.55,1.83
# 239996,-1.28,-0.18,0.85
# 240996,-19.17,1.46,-3.72
# 241996,9.28,-0.98,3.30
# 242996,1.83,-0.79,1.59
# 243996,3.17,-0.92,1.40
# 244996,6.71,-1.16,2.20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 15
#      12 writer.writerow(['Timestamp', 'X', 'Y', 'Z'])  # Write the header row
#      14 while True:
# ---> 15     if ser.in_waiting > 0:  # Check if there's data in the serial buffer
#      16         data = ser.readline().decode('utf-8').strip()  # Read a line of data
#      17         # Split the data by commas (assuming it's in CSV format)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\serial\serialwin32.py:258, in Serial.in_waiting(self)
#     256 flags = win32.DWORD()
#     257 comstat = win32.COMSTAT()
# --> 258 if not win32.ClearCommError(self._port_handle, ctypes.byref(flags), ctypes.byref(comstat)):
#     259     raise SerialException("ClearCommError failed ({!r})".format(ctypes.WinError()))
#     260 return comstat.cbInQue
#
# KeyboardInterrupt:
